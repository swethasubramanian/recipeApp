# %% [markdown]
# # Plan your meals from CSA shit!
# Recipe data source: Epicurious.com

# %%
## Import all libraries
import pandas as pd
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException
from bs4 import BeautifulSoup
import numpy as np
from collections import defaultdict
import urllib2, time, pickle

# SQL packages
from sqlalchemy import create_engine
from sqlalchemy_utils import database_exists, create_database
import psycopg2
from nltk.stem.wordnet import WordNetLemmatizer

# %% [markdown]
# ### I am scraping for the recipes using vegetables typically grown in my old CSA, because they have that list and also because they have some sample boxes that I can test my algorithm on!

# %%
testCsaUrl = "http://driftlessorganics.com/csa-2/recipes/"
page = urllib2.urlopen(testCsaUrl)
vegetableSoup = BeautifulSoup(page, "html.parser")
veggiesHTML = vegetableSoup.findAll('span', style="color: #339966;")

vegetables = []
for veggie in veggiesHTML:
    if veggie.a:
        vegetables.append(veggie.a.get_text().lower())
 
### Great I have a list of vegetables! Now to clean them up! Like split up Cauliflower and Romanesco!
vegetablesSplit = [vegetable.split('&',1) for vegetable in vegetables]
veggieList = sum(vegetablesSplit, [])
#veggiesList = veggieList[:15]

# %%
foodSpoilURL = "http://ohmyveggies.com/how-to-prevent-food-spoilage-with-careful-meal-planning/"
#page = urllib2.urlopen(foodSpoilURL)
hdr = {'User-Agent':'Mozilla/5.0'}
req = urllib2.Request(foodSpoilURL,headers=hdr)
page = urllib2.urlopen(req)
foodSpoilSoup = BeautifulSoup(page, "html.parser")
foodSpoilHtml = foodSpoilSoup.findAll("p")

foodSpoilsinDate12Days = foodSpoilHtml[7].get_text().split()
foodSpoilsin35Days = foodSpoilHtml[9].get_text().split()
foodSpoilsin67Days = foodSpoilHtml[11].get_text().split()
foodSpoilsGreatWeek = foodSpoilHtml[13].get_text().split()

#foodSpoilDates = [foodSpoilsinDate12Days, foodSpoilsin35Days, foodSpoilsin67Days, foodSpoilsGreatWeek]

foodSpoilsinDate12Days_lemma = [lemmatizePhrase(str(veggie).lower()) for veggie in foodSpoilsinDate12Days]   
foodSpoilsinDate35Days_lemma = [lemmatizePhrase(str(veggie).lower()) for veggie in foodSpoilsin35Days]  
foodSpoilsinDate67Days_lemma = [lemmatizePhrase(str(veggie).lower()) for veggie in foodSpoilsin67Days] 
foodSpoilsGreatWeek_lemma = [lemmatizePhrase(str(veggie).lower()) for veggie in foodSpoilsGreatWeek] 
foodSpoilsGreatWeek_lemma = foodSpoilsGreatWeek_lemma[:13] + foodSpoilsGreatWeek_lemma[22:]
foodSpoilsGreatWeek_lemma.append('dill')
foodSpoilsinDate35Days_lemma = foodSpoilsinDate35Days_lemma[:2]+foodSpoilsinDate35Days_lemma[14:]
foodSpoilsinDate35Days_lemma.append('basil')

veggies1 = foodSpoilsinDate12Days_lemma + foodSpoilsinDate35Days_lemma + \
foodSpoilsinDate67Days_lemma + foodSpoilsGreatWeek_lemma
veggies1.remove('and')
veggies1.remove('other')
veggies1.remove('hot')
veggies2 = list(set(veggies1)-set(veggieList))

# %%
list(set(veggieList)-set(veggies1))

# %% [markdown]
# ### Scrap epicurious.com for recipes for every vegetable in my CSA list!
# because they are free, I see they have tags (gluten-free/kid friendly etc), reviews, ratings and sort recipes by ingredients, calorie info
#
# *** Will not scrap data from a recipe without images

# %%
browser = webdriver.Chrome("chromedriver")
def getRecipes(df, veggiesList, pageNumber, visiting = None):
    if visiting is None:
        visiting = set()
        if len(veggiesList) == 0:
            return df
        else:
            veggie = veggiesList.pop()
            visiting.add(veggie)
            print veggie, pageNumber
        
    recipes = defaultdict(list)
    
    pageSize = 30
    resultOffset = pageNumber*pageSize + 1
    url = \
    "http://www.epicurious.com/tools/searchresults?search=%s&sort=1&type=simple&pageNumber=%s&pageSize=%s&resultOffset=%s"%\
    (list(visiting)[0], pageNumber, pageSize, resultOffset)
    browser.get(url)
    time.sleep(2.0)
    recipeListPage = browser.page_source
    soup2 = BeautifulSoup(recipeListPage, "html.parser")
    
    
    #allRecipes.append(soup2.find('div', class_='sr_rows clearfix firstResult').a.get('href'))
    if soup2.find('div', class_='sr_rows clearfix firstResult') is None:
        return getRecipes(df, veggiesList, 1, visiting = None)
        
    recipes['recipe'].append(soup2.find('div', class_='sr_rows clearfix firstResult').a.get('href'))
    recipes['searchIngredient'].append(list(visiting)[0])
    recipesDf = pd.DataFrame.from_dict(recipes)
    df = pd.concat([df, recipesDf])
    
    a=soup2.findAll('div', class_='sr_rows clearfix ')
    count = 0
    for recipeList in a:
        count += 1
        if recipeList.find('img').get('src') != "/css/i/recipe-img-icon.png":
            #allRecipes.append(recipeList.a.get('href'))
            recipes['recipe'].append(recipeList.a.get('href'))
            recipes['searchIngredient'].append(list(visiting)[0])
            recipesDf = pd.DataFrame.from_dict(recipes)
            df = pd.concat([df, recipesDf])
    
    if (count < 28) | (pageNumber > 100):
        return getRecipes(df, veggiesList, 1, visiting = None)
    else:
        return getRecipes(df, veggiesList, pageNumber+1, visiting)
  
df = pd.DataFrame(columns = ('recipe', 'searchIngredient'))
allRecipes = []
initDf = getRecipes(df, ['vegetarian'], 1)
initDf.to_pickle('recipeList4')

# %%
### Had saved recipes per 
df = pd.DataFrame(columns = ('recipe', 'searchIngredient'))
allRecipes = []
#initDf = getRecipes(df, veggies1, 1)
#initDf.to_pickle('recipeList3')
df1 = pd.read_pickle('/Volumes/LittleOne/Insight/RecipeApp/notebooks/recipeList')
df2 = pd.read_pickle('/Volumes/LittleOne/Insight/RecipeApp/notebooks/recipeList2')
df3 = pd.read_pickle('/Volumes/LittleOne/Insight/RecipeApp/notebooks/recipeList3')
df6 = pd.read_pickle('/Volumes/LittleOne/Insight/RecipeApp/notebooks/recipeList4')
df4 = pd.read_pickle('/Volumes/LittleOne/Insight/RecipeApp/notebooks/recipeList6')
df5 = pd.read_pickle('/Volumes/LittleOne/Insight/RecipeApp/notebooks/recipeList5')
df = pd.concat([df1, df2, df3, df4, df5,df6]).drop_duplicates('recipe')

# %%
len(df)
# Out:
# 8491

# %%
browser = webdriver.Chrome("chromedriver")
rDf = pd.DataFrame(columns = ('id', 'name', 'tags', 'description', 'imageURL', 'rating', 'willPrepareAgainRating',\
                                  'reviewCount', 'numberOfServings', 'activeTime', 'totalTime', 'numberOfCalories',\
                                  'ingredientsList', 'reviewText'))
recipes = defaultdict(list)
recipeIDs = list(set(df.recipe))
oldRecipesDf1 =  pd.read_pickle('/Volumes/LittleOne/Insight/RecipeApp/notebooks/recipesDb1')
oldRecipesDf2 =  pd.read_pickle('/Volumes/LittleOne/Insight/RecipeApp/notebooks/recipesDb2')
oldRecipesDf3 =  pd.read_pickle('/Volumes/LittleOne/Insight/RecipeApp/notebooks/recipesDb3')
oldRecipesDf4 =  pd.read_pickle('/Volumes/LittleOne/Insight/RecipeApp/notebooks/recipesDb4')
oldRecipesDf5 =  pd.read_pickle('/Volumes/LittleOne/Insight/RecipeApp/notebooks/recipesDb5')
oldRecipesDf6 =  pd.read_pickle('/Volumes/LittleOne/Insight/RecipeApp/notebooks/recipesDb6')
oldRecipesDf7 =  pd.read_pickle('/Volumes/LittleOne/Insight/RecipeApp/notebooks/recipesDb7')
oldRecipesDf8 =  pd.read_pickle('/Volumes/LittleOne/Insight/RecipeApp/notebooks/recipesDb8')
oldRecipesDf = pd.concat([oldRecipesDf1, oldRecipesDf2, oldRecipesDf3, oldRecipesDf4, oldRecipesDf5,\
                          oldRecipesDf6, oldRecipesDf7, oldRecipesDf8])
recipeIDs = list(set(df.recipe)-set(oldRecipesDf.id)) 

for recipeID in recipeIDs:
    url = "http://www.epicurious.com"+recipeID
    browser.get(url)
    
    recipePage = browser.page_source
    soup = BeautifulSoup(recipePage, "html.parser")
    if (soup.find(itemprop = "ratingValue") is not None) & (soup.find(itemprop = "keywords") is not None):
        recipes['id'].append(recipeID)
        recipes['name'].append(soup.find(property = "og:title").get('content'))
        if soup.find(itemprop = "keywords") is None:
            recipes['tags'].append(' ')
        else:
            recipes['tags'].append(soup.find(itemprop = "keywords").get('content'))
        if soup.find(property = "og:description") is None:
            recipes['description'].append(' ')
        else:
            recipes['description'].append(soup.find(property = "og:description").get('content'))
        recipes['imageURL'].append(soup.find(property = "og:image").get('content'))
    
    
        recipes['rating'].append(soup.find(itemprop = "ratingValue").get('content'))
        recipes['willPrepareAgainRating'].append(soup.find('div', class_="prepare-again-rating").span.get_text())
        recipes['reviewCount'].append(soup.find('span', class_="reviews-count").get_text())

        if soup.find('div', class_ = "recipe-summary") is None:
            recipes['numberOfServings'].append(' ')
        else:
            recipes['numberOfServings'].append(soup.find('div', class_ = "recipe-summary").dd.get_text())

        if ((soup.find('dd', class_ = "active-time")) is None) |  (soup.find('dd', class_ = "total-time") is None):
            recipes['activeTime'].append(' ')
            recipes['totalTime'].append(' ')
        else:
            recipes['activeTime'].append(soup.find('dd', class_ = "active-time").get_text())
            recipes['totalTime'].append(soup.find('dd', class_ = "total-time").get_text())

        if soup.find(itemprop = "calories") is None:
            recipes['numberOfCalories'].append(' ')
        else:
            recipes['numberOfCalories'].append(soup.find(itemprop = "calories").get_text())

        # Create a list of ingredients
        ingredientsList = [] 
        ingredients = soup.findAll(itemprop = "ingredients")
        for ingredient in ingredients:
            ingredientsList.append(ingredient.get_text())
        recipes['ingredientsList'].append(ingredientsList)

        # Create a list of reviews
        reviewText = []
        reviews = soup.findAll('div', class_ = "review-text")
        for review in reviews:
            reviewText.append(review.p.get_text())
        recipes['reviewText'].append(reviewText)

recipesDf = pd.DataFrame.from_dict(recipes)
recipesDf.to_pickle('recipesDb9')

# %%
recipesDf = pd.DataFrame.from_dict(recipes)
recipesDf.to_pickle('recipesDb9')

# %%
oldRecipesDf1 =  pd.read_pickle('/Volumes/LittleOne/Insight/RecipeApp/notebooks/recipesDb1')
oldRecipesDf2 =  pd.read_pickle('/Volumes/LittleOne/Insight/RecipeApp/notebooks/recipesDb2')
oldRecipesDf3 =  pd.read_pickle('/Volumes/LittleOne/Insight/RecipeApp/notebooks/recipesDb3')
oldRecipesDf4 =  pd.read_pickle('/Volumes/LittleOne/Insight/RecipeApp/notebooks/recipesDb4')
oldRecipesDf5 =  pd.read_pickle('/Volumes/LittleOne/Insight/RecipeApp/notebooks/recipesDb5')
oldRecipesDf6 =  pd.read_pickle('/Volumes/LittleOne/Insight/RecipeApp/notebooks/recipesDb6')
oldRecipesDf7 =  pd.read_pickle('/Volumes/LittleOne/Insight/RecipeApp/notebooks/recipesDb7')
oldRecipesDf8 =  pd.read_pickle('/Volumes/LittleOne/Insight/RecipeApp/notebooks/recipesDb8')
oldRecipesDf = pd.concat([oldRecipesDf1, oldRecipesDf2, oldRecipesDf3, oldRecipesDf4, oldRecipesDf5,\
                          oldRecipesDf6, oldRecipesDf7, oldRecipesDf8])
recipeIDs = list(set(df.recipe)-set(oldRecipesDf.id))
len(recipeIDs), len(oldRecipesDf)
# Out:
# (1972, 6519)

# %%
recipeIDs[1500:]
# Out:
# [u'/recipes/food/views/chicken-and-sausage-gumbo-380586',
#  u'/recipes/food/views/chipotle-white-cheddar-mashed-potatoes-236528',
#  u'/recipes/food/views/red-wine-braised-short-rib-stew-with-potatoes-carrots-and-mushrooms',
#  u'/recipes/food/views/seared-bluefish-with-charred-corn-warm-tomato-salad-51243430',
#  u'/recipes/food/views/pot-roast-with-caramelized-onions-and-roasted-carrots-236745',
#  u'/recipes/food/views/turkish-style-lamb-burgers-with-walnut-sauce-231647',
#  u'/recipes/food/views/roasted-fingerlings-with-red-and-yellow-piperade-240410',
#  u'/recipes/food/views/thai-salad-with-whole-grain-brown-rice-and-chicken-51263960',
#  u'/recipes/food/views/cactus-pear-sorbets-14155',
#  u'/recipes/food/views/easy-provencal-lamb-360869',
#  u'/recipes/food/views/burnt-carrots-with-goat-cheese-parsley-arugula-and-crispy-garlic-chips-354729',
#  u'/recipes/food/views/sausage-ragout-with-linguine-350157',
#  u'/recipes/food/views/lime-cilantro-sweet-potatoes-109459',
#  u'/recipes/food/views/roasted-sweet-potato-wedges-with-smoked-chile-cream-361831',
#  u'/recipes/food/views/spaghetti-with-spicy-tomato-olive-sauce-107598',
#  u'/recipes/food/views/sausage-and-potato-breakfast-casserole-4387',
#  u'/recipes/food/views/olive-caper-relish-107823',
#  u'/recipes/food/views/arugula-salad-with-olives-pancetta-and-parmesan-shavings-237091',
#  u'/recipes/food/views/beet-and-goat-cheese-salad-with-pistachios-107426',
#  u'/recipes/food/views/fennel-and-radicchio-salad-with-olive-vinaigrette-388551',
#  u'/recipes/food/views/sauteed-halibut-with-arugula-roasted-beets-and-horseradish-creme-fraiche-358351',
#  u'/recipes/food/views/rosemary-concord-shrub-56389972',
#  u'/recipes/food/views/duck-fat-potato-galette-with-caraway-and-sweet-onions-368933',
#  u'/recipes/food/views/snap-beans-with-mustard-and-country-ham-350515',
#  u'/recipes/food/views/artichokes-braised-with-garlic-and-thyme-231804',
#  u'/recipes/food/views/cornish-beef-and-vegetable-turnovers-105405',
#  u'/recipes/food/views/sesame-noodles-with-chili-oil-and-scallions-51170210',
#  u'/recipes/food/views/dungeness-crab-and-heirloom-bean-brandade-350424',
#  u'/recipes/food/views/black-cod-with-swiss-chard-olives-and-lemon-51141000',
#  u'/recipes/food/views/easy-chicken-fried-rice-51264280',
#  u'/recipes/food/views/braised-oxtails-with-star-anise-and-chinese-greens-236874',
#  u'/recipes/food/views/rhubarb-roulade-106548',
#  u'/recipes/food/views/eggs-in-purgatory-with-artichoke-hearts-potatoes-and-capers-357495',
#  u'/recipes/food/views/mushroom-soup-with-hazelnut-gremolata-350094',
#  u'/recipes/food/views/sesame-crusted-salmon-51217620',
#  u'/recipes/food/views/veggi-prosciutto-pizza-51150600',
#  u'/recipes/food/views/chestnut-and-sherry-soup-with-truffle-garnish-240483',
#  u'/recipes/food/views/smoked-salmon-crepe-torte-355371',
#  u'/recipes/food/views/curried-red-lentil-and-swiss-chard-stew-with-garbanzo-beans-233385',
#  u'/recipes/food/views/chicken-skewers-with-meyer-lemon-salsa-380587',
#  u'/recipes/food/views/wild-rice-stuffing-with-pearl-onions-dried-cherries-and-apricots-100460',
#  u'/recipes/food/views/corn-zucchini-and-poblano-chili-saute-104313',
#  u'/recipes/food/views/sausage-roasted-red-pepper-and-spinach-torta-rustica-350774',
#  u'/recipes/food/views/baked-mini-pumpkin-pots-51200620',
#  u'/recipes/food/views/saffron-chicken-breasts-with-english-pea-puree-pea-shoots-and-mint-234429',
#  u'/recipes/food/views/grilled-spot-prawns-365819',
#  u'/recipes/food/views/grilled-maple-brined-pork-chops-106239',
#  u'/recipes/food/views/rhubarb-and-white-chocolate-lattice-tart-109501',
#  u'/recipes/food/views/southwest-corn-bread-stuffing-with-corn-and-green-chilies-105807',
#  u'/recipes/food/views/red-cabbage-salad-with-green-apple-lingonberry-preserves-and-toasted-walnuts-356771',
#  u'/recipes/food/views/chocolate-hazelnut-torte-234278',
#  u'/recipes/food/views/smoked-whitefish-on-cucumber-rounds-231178',
#  u'/recipes/food/views/linguine-with-red-bell-peppers-and-kalamata-olives-360029',
#  u'/recipes/food/views/steamed-blue-crabs-with-black-ginger-dipping-sauce-232305',
#  u'/recipes/food/views/mixed-mushroom-tamales-230996',
#  u'/recipes/food/views/caramelized-onion-with-pancetta-and-rosemary-stuffing-51134490',
#  u'/recipes/food/views/soba-with-grilled-asparagus-and-sea-scallops-with-sweet-miso-sauce-354711',
#  u'/recipes/food/views/linguine-ai-frutti-di-mare-238646',
#  u'/recipes/food/views/red-and-white-endive-salad-241726',
#  u'/recipes/food/views/rhubarb-coffee-cake-395390',
#  u'/recipes/food/views/shrimp-salad-rolls-234979',
#  u'/recipes/food/views/warm-goat-cheese-toasts-with-rosemary-walnuts-and-honey-108799',
#  u'/recipes/food/views/soupe-au-pistou-102430',
#  u'/recipes/food/views/beef-stroganov-105587',
#  u'/recipes/food/views/goat-tacos-242840',
#  u'/recipes/food/views/leek-and-celery-pie-234978',
#  u'/recipes/food/views/whole-stuffed-artichokes-braised-in-white-wine-106245',
#  u'/recipes/food/views/burrata-cheese-with-shaved-vegetable-salad-231426',
#  u'/recipes/food/views/cheesy-chicken-burrito-with-chips-and-salsa-240527',
#  u'/recipes/food/views/breakfast-sandwich-51178000',
#  u'/recipes/food/views/lamb-burgers-with-red-and-green-tomato-chutney-103665',
#  u'/recipes/food/views/jasmine-honey-lassi-358950',
#  u'/recipes/food/views/halibut-with-carrots-fennel-lemon-and-garlic-231873',
#  u'/recipes/food/views/parker-house-rolls-51122600',
#  u'/recipes/food/views/the-spring-forward-51265010',
#  u'/recipes/food/views/rack-of-lamb-with-garlic-and-herbs-1222178',
#  u'/recipes/food/views/winter-salad-with-sauteed-bay-scallops-107694',
#  u'/recipes/food/views/steak-with-red-wine-mushroom-sauce-51219610',
#  u'/recipes/food/views/lebanese-style-stuffed-eggplant-358052',
#  u'/recipes/food/views/orzo-salad-388789',
#  u'/recipes/food/views/roasted-red-peppers-and-cauliflower-with-caper-vinaigrette-242872',
#  u'/recipes/food/views/potato-and-root-vegetables-mash-1206',
#  u'/recipes/food/views/chorizo-scrambled-eggs-105908',
#  u'/recipes/food/views/wine-cake-with-macerated-strawberries-234275',
#  u'/recipes/food/views/ditalini-risotto',
#  u'/recipes/food/views/root-vegetable-tagine-with-sweet-potatoes-carrots-turnips-and-spice-roasted-chickpeas-361252',
#  u'/recipes/food/views/cabbage-and-carrot-slaw-with-walnut-zaatar-pesto-56389710',
#  u'/recipes/food/views/chicken-quesadillas-108378',
#  u'/recipes/food/views/sweet-potato-with-toasted-coconut-394652',
#  u'/recipes/food/views/root-vegetable-and-mushroom-pie-with-rosemary-biscuit-topping-351510',
#  u'/recipes/food/views/spicy-roasted-cauliflower-with-sriracha-and-sesame-51238830',
#  u'/recipes/food/views/smoked-trout-spread-233241',
#  u'/recipes/food/views/roasted-carrots-350879',
#  u'/recipes/food/views/avocado-tomato-salsa-358270',
#  u'/recipes/food/views/white-beans-with-broccoli-rabe-and-lemon-51205290',
#  u'/recipes/food/views/grilled-steaks-with-red-chile-sauce-108336',
#  u'/recipes/food/views/croatian-moussaka-230458',
#  u'/recipes/food/views/cracked-pepper-focaccia-with-truffle-oil-104687',
#  u'/recipes/food/views/dublin-coddle-51224810',
#  u'/recipes/food/views/pumpkin-spoon-bread-51198680',
#  u'/recipes/food/views/cornbread-casserole-and-butternut-squash-mushrooms-and-ancho-mole-233151',
#  u'/recipes/food/views/ricotta-basil-tomato-tea-sandwiches',
#  u'/recipes/food/views/mango-and-mint-salsa-106279',
#  u'/recipes/food/views/creamy-leek-soup-238442',
#  u'/recipes/food/views/fig-and-onion-bruschetta-351069',
#  u'/recipes/food/views/savory-pumpkin-pie-soup-with-cinnamon-marshmallows-pepita-streusel-and-whipped-creme-fraiche-368718',
#  u'/recipes/food/views/apple-filled-acorn-squash-rings-with-curry-butter-105808',
#  u'/recipes/food/views/gazpacho-357151',
#  u'/recipes/food/views/chicken-under-a-brick-51175280',
#  u'/recipes/food/views/penne-with-chicken-shiitake-mushrooms-and-capers-107091',
#  u'/recipes/food/views/steamed-mussels-with-tomato-and-chorizo-broth-56389715',
#  u'/recipes/food/views/porcupine-meatballs-350174',
#  u'/recipes/food/views/grilled-lamb-sandwiches-with-grilled-green-onions-101699',
#  u'/recipes/food/views/chinese-broccoli-242053',
#  u'/recipes/food/views/mango-cucumber-salsa-14022',
#  u'/recipes/food/views/bengali-style-fish-in-yogurt-curry-367030',
#  u'/recipes/food/views/baby-carrot-confit-with-orange-juice-and-cumin-242121',
#  u'/recipes/food/views/strawberry-tarts-with-ginger-nut-crust-395925',
#  u'/recipes/food/views/honey-lemon-custard-with-fruit-51104290',
#  u'/recipes/food/views/pesto-crusted-chicken-breasts-106320',
#  u'/recipes/food/views/pork-tenderloin-churrasco-108572',
#  u'/recipes/food/views/lemon-blinis-with-caviar-and-scallion-creme-fraiche-388549',
#  u'/recipes/food/views/slow-roasted-black-cod-with-red-chermoula-56389891',
#  u'/recipes/food/views/mexican-style-stuffed-potatoes-103625',
#  u'/recipes/food/views/dried-fig-apricot-and-cherry-slump-356951',
#  u'/recipes/food/views/steamed-whole-fish-with-ginger-scallions-and-soy-51115200',
#  u'/recipes/food/views/bon-ton-style-fried-chicken-103662',
#  u'/recipes/food/views/spaghetti-with-no-cook-tomato-sauce-and-hazelnuts-56389869',
#  u'/recipes/food/views/sweet-and-tangy-roasted-tomatoes-56389650',
#  u'/recipes/food/views/roasted-balsamic-beets-56390051',
#  u'/recipes/food/views/grill-basket-stir-fry-vegetables-51180410',
#  u'/recipes/food/views/gluten-free-sesame-sandwich-bread-241927',
#  u'/recipes/food/views/new-england-clam-and-corn-chowder-with-herbs-350962',
#  u'/recipes/food/views/vietnamese-chicken-noodle-soup-51234630',
#  u'/recipes/food/views/potato-chip-frittatas-351289',
#  u'/recipes/food/views/dill-chicken-paillards-with-tomato-dill-relish-354971',
#  u'/recipes/food/views/roasted-monkfish-fennel-and-chestnut-tagine-105598',
#  u'/recipes/food/views/fiesta-chicken-51264290',
#  u'/recipes/food/views/bacon-and-potato-frittata-51107800',
#  u'/recipes/food/views/braised-turnips-with-poppy-seed-bread-crumbs-241507',
#  u'/recipes/food/views/ramp-and-buttermilk-biscuits-with-cracked-coriander-352036',
#  u'/recipes/food/views/guacamole-with-lime-and-roasted-chilies-106972',
#  u'/recipes/food/views/golden-onion-pie-356012',
#  u'/recipes/food/views/pea-and-bacon-risotto-351151',
#  u'/recipes/food/views/pork-tenderloin-with-spiced-rhubarb-chutney-1759',
#  u'/recipes/food/views/crab-sweet-corn-cakes-365969',
#  u'/recipes/food/views/glazed-hakurei-turnips-368274',
#  u'/recipes/food/views/onion-anchovy-galette-358118',
#  u'/recipes/food/views/wakame-51140800',
#  u'/recipes/food/views/potted-chicken-rilletes-354909',
#  u'/recipes/food/views/celery-on-celery-salad',
#  u'/recipes/food/views/roasted-pork-tenderloin-with-apples-363378',
#  u'/recipes/food/views/spicy-asian-style-noodles-with-clams-103780',
#  u'/recipes/food/views/bean-bello-burger-351391',
#  u'/recipes/food/views/minty-pea-soup-51154900',
#  u'/recipes/food/views/broiled-salmon-with-scallions-and-sesame',
#  u'/recipes/food/views/roasted-rosemary-potatoes-51170330',
#  u'/recipes/food/views/asian-steak-and-noodle-salad-235018',
#  u'/recipes/food/views/smoked-salmon-platter-with-dill-sour-cream-240664',
#  u'/recipes/food/views/goose-stew-with-barley-and-celery-root-51197630',
#  u'/recipes/food/views/spanish-anchovy-fennel-and-preserved-lemon-salad-239825',
#  u'/recipes/food/views/spring-pea-frittata-239224',
#  u'/recipes/food/views/lemony-chicken-soup-with-farro-white-beans-and-kale',
#  u'/recipes/food/views/spicy-beans-with-wilted-greens-51214650',
#  u'/recipes/food/views/crispy-creamy-rock-shrimp-with-sweet-chile-aioli-and-apple-slaw-363589',
#  u'/recipes/food/views/plum-crisp-100777',
#  u'/recipes/food/views/beef-barley-soup-with-wild-mushrooms-and-parsnips-102363',
#  u'/recipes/food/views/chicken-rice-and-mango-in-lettuce-wraps-232487',
#  u'/recipes/food/views/pickled-shrimp-356356',
#  u'/recipes/food/views/stir-fried-buckwheat-51195240',
#  u'/recipes/food/views/farmstand-gazpacho-242766',
#  u'/recipes/food/views/summer-fruit-salad-with-mint-sugar-109657',
#  u'/recipes/food/views/butternut-squash-kale-and-crunchy-pepitas-taco-51249020',
#  u'/recipes/food/views/peppercorn-steaks-with-bourbon-sauce-106315',
#  u'/recipes/food/views/ancho-tortilla-soup-56390048',
#  u'/recipes/food/views/lamb-and-eggplant-moussaka-352510',
#  u'/recipes/food/views/buffalo-chicken-wings-101925',
#  u'/recipes/food/views/broccoli-with-orecchiette-351170',
#  u'/recipes/food/views/miso-glazed-tuna-kebabs-242631',
#  u'/recipes/food/views/herbed-potato-salad-101914',
#  u'/recipes/food/views/paella-valenciana-357152',
#  u'/recipes/food/views/fava-beans-with-creme-fraiche-and-mint-352371',
#  u'/recipes/food/views/lobster-avocado-and-grapefruit-salad-109004',
#  u'/recipes/food/views/braised-turkey-with-root-vegetables-51209710',
#  u'/recipes/food/views/butternut-squash-soup-with-pumpkin-butter-51122000',
#  u'/recipes/food/views/plum-hazelnut-torte-100776',
#  u'/recipes/food/views/caesar-potato-salad-with-sugar-snap-peas-353351',
#  u'/recipes/food/views/braised-trout-in-chilli-bean-sauce-em-dou-ban-yu-em-51147400',
#  u'/recipes/food/views/sweet-potato-pancakes-with-honey-cinnamon-butter-239216',
#  u'/recipes/food/views/quick-sweet-potato-mushroom-and-black-bean-burrito',
#  u'/recipes/food/views/kale-and-mushrooms-with-creamy-polenta-233922',
#  u'/recipes/food/views/pappardelle-with-pancetta-broccoli-rabe-and-pine-nuts-234397',
#  u'/recipes/food/views/deconstructed-caprese-51188630',
#  u'/recipes/food/views/israeli-couscous-with-roasted-butternut-squash-and-preserved-lemon-102250',
#  u'/recipes/food/views/farfalle-with-golden-beets-beet-greens-and-pine-nuts-351260',
#  u'/recipes/food/views/spiced-lamb-hand-pies-51263680',
#  u'/recipes/food/views/branzino-and-roasted-baby-vegetables-with-tarragon-chive-oil-358193',
#  u'/recipes/food/views/penne-with-tomato-pesto-and-smoked-mozzarella-394794',
#  u'/recipes/food/views/grilled-street-corn-salad-with-cilantro-butter-shrimp-pico-de-gallo-and-avocado-puree-51180800',
#  u'/recipes/food/views/lamb-souvlaki-sandwiches-with-greek-salad-and-tsatsiki-sauce-107978',
#  u'/recipes/food/views/grilled-jerk-pork-with-curried-peach-relish-232488',
#  u'/recipes/food/views/bresaola-with-arugula-fennel-and-manchego-cheese-109360',
#  u'/recipes/food/views/smothered-yellow-squash-with-basil-109752',
#  u'/recipes/food/views/korean-steak-tacos-51221610',
#  u'/recipes/food/views/poached-apples-with-vanilla-yogurt-368301',
#  u'/recipes/food/views/pot-roast-in-rich-gravy-394970',
#  u'/recipes/food/views/rhubarb-fennel-gin-cocktail',
#  u'/recipes/food/views/burgers-with-mozzarella-and-spinach-arugula-pesto-235619',
#  u'/recipes/food/views/oven-dried-tomato-tart-with-goat-cheese-and-black-olives-232540',
#  u'/recipes/food/views/two-potato-salad-with-creole-mustard-bacon-and-arugula-353289',
#  u'/recipes/food/views/potatoes-roasted-with-olive-oil-and-bay-leaves-108250',
#  u'/recipes/food/views/whipped-gorgonzola-56389724',
#  u'/recipes/food/views/veggie-sushi-rolls-367009',
#  u'/recipes/food/views/cranberry-fig-and-pinot-noir-chutney-367509',
#  u'/recipes/food/views/mango-curry-shrimp-salad-in-wonton-cups-105651',
#  u'/recipes/food/views/halibut-with-zucchini-salsa-verde-360269',
#  u'/recipes/food/views/cranberry-sauce-with-dried-cherries-and-cloves-15656',
#  u'/recipes/food/views/balsamic-mixed-vegetable-roast-104866',
#  u'/recipes/food/views/sesame-miso-vinaigrette-51210220',
#  u'/recipes/food/views/scallion-fish-with-sesame-kale-51198470',
#  u'/recipes/food/views/saffron-potatoes-109032',
#  u'/recipes/food/views/mixed-lettuces-and-kohlrabi-with-creamy-sumac-dressing',
#  u'/recipes/food/views/roast-beef-tenderloin-with-caesar-crust-368967',
#  u'/recipes/food/views/balsamic-glazed-pork-chops-233982',
#  u'/recipes/food/views/spelt-crust-pizza-with-fennel-prosciutto-and-apples-366669',
#  u'/recipes/food/views/asian-chicken-and-water-chestnut-patties-106518',
#  u'/recipes/food/views/sumo-stew-chanko-nabe-with-shrimp-meatballs-and-bok-choy',
#  u'/recipes/food/views/cornbread-chorizo-stuffing-106802',
#  u'/recipes/food/views/gingersnap-crumble-ice-cream-tart-with-chunky-pineapple-sauce-101530',
#  u'/recipes/food/views/chilled-buttermilk-soup-106734',
#  u'/recipes/food/views/grilled-grass-fed-rib-eye-steaks-with-balsamic-caper-vinaigrette-352592',
#  u'/recipes/food/views/duck-egg-cake-with-rosemary-51197420',
#  u'/recipes/food/views/smoked-paprika-salmon-with-spinach-56390045',
#  u'/recipes/food/views/sauteed-snow-peas-11850',
#  u'/recipes/food/views/roast-leg-of-lamb-with-mint-aioli-107201',
#  u'/recipes/food/views/irish-channel-corned-beef-and-cabbage-51224220',
#  u'/recipes/food/views/rib-eye-roast-with-chianti-pan-vegetables-and-balsamic-glaze-106316',
#  u'/recipes/food/views/turkey-empanadas-355775',
#  u'/recipes/food/views/halibut-in-chard-leaves-with-lemon-thyme-butter-237309',
#  u'/recipes/food/views/lemon-tahini-sauce-354109',
#  u'/recipes/food/views/tagliatelle-with-fresh-corn-pesto-360209',
#  u'/recipes/food/views/chipotle-braised-chicken-358000',
#  u'/recipes/food/views/snow-peas-with-toasted-almonds-352035',
#  u'/recipes/food/views/roasted-butternut-squash-with-lime-juice-240368',
#  u'/recipes/food/views/sauteed-broccoli-rabe-350629',
#  u'/recipes/food/views/barbecue-pulled-turkey-sandwiches-355752',
#  u'/recipes/food/views/red-wine-brasato-with-glazed-root-vegetables-237035',
#  u'/recipes/food/views/tomato-gratin-103816',
#  u'/recipes/food/views/orecchiette-with-spiced-duck-ragu-109057',
#  u'/recipes/food/views/jade-dumplings-with-soy-sesame-dipping-sauce-107838',
#  u'/recipes/food/views/chickpea-pizza-353783',
#  u'/recipes/food/views/smoked-turkey-plum-and-fennel-salad-243166',
#  u'/recipes/food/views/trout-with-tropical-fruit-salsa-and-mixed-greens-108562',
#  u'/recipes/food/views/grilled-eggplant-stacks-with-tomato-and-feta-232478',
#  u'/recipes/food/views/seared-scallops-on-shrimp-and-truffle-risotto-108544',
#  u'/recipes/food/views/crispy-seasoned-oven-fries-394769',
#  u'/recipes/food/views/beet-salad-with-cornbread-croutons-and-country-ham-351043',
#  u'/recipes/food/views/the-house-salad-51120200',
#  u'/recipes/food/views/bedouin-salsa-355011',
#  u'/recipes/food/views/pizza-with-sausage-tomatoes-and-basil-239903',
#  u'/recipes/food/views/gratineed-gnocchi-with-spinach-and-ricotta-234669',
#  u'/recipes/food/views/vegetable-and-chickpea-ragout-355370',
#  u'/recipes/food/views/beet-rhubarb-and-orange-salad-357916',
#  u'/recipes/food/views/grilled-steak-and-onions-with-rosemary-balsamic-butter-sauce-235595',
#  u'/recipes/food/views/spring-lamb-with-grilled-baby-artichokes-mr-bean-363469',
#  u'/recipes/food/views/eggplant-caviar-with-fresh-tomato-coulis-103221',
#  u'/recipes/food/views/polenta-with-fresh-herbs-and-white-cheddar-cheese-102175',
#  u'/recipes/food/views/creamy-polenta-352671',
#  u'/recipes/food/views/poached-oranges-with-candied-zest-and-ginger-233286',
#  u'/recipes/food/views/apple-harvest-salad-56390047',
#  u'/recipes/food/views/green-panzanella-with-pickled-shallot-51179200',
#  u'/recipes/food/views/roasted-carrot-parsnip-and-potato-coins-356319',
#  u'/recipes/food/views/arugula-and-fontina-frittata-231657',
#  u'/recipes/food/views/sweet-onion-quesadillas-11920',
#  u'/recipes/food/views/roasted-and-charred-broccoli-with-peanuts-51260420',
#  u'/recipes/food/views/spiced-beef-patties-with-couscous-107489',
#  u'/recipes/food/views/caviar-pancakes-109426',
#  u'/recipes/food/views/tuscan-beans-104559',
#  u'/recipes/food/views/thai-chicken-coconut-soup-241463',
#  u'/recipes/food/views/candied-nuts-with-smoked-almonds-51133440',
#  u'/recipes/food/views/chile-braised-short-ribs-51147480',
#  u'/recipes/food/views/whole-wheat-oatmeal-pancakes-241530',
#  u'/recipes/food/views/lemon-lemon-loaf-350989',
#  u'/recipes/food/views/portobello-and-poblano-enchiladas',
#  u'/recipes/food/views/tomato-and-crab-soup-366751',
#  u'/recipes/food/views/herbed-crepes-with-smoked-salmon-and-radishes-108995',
#  u'/recipes/food/views/grilled-sausages-with-figs-and-mixed-greens-360089',
#  u'/recipes/food/views/lamb-stew-with-lemon-and-figs-233923',
#  u'/recipes/food/views/waldorf-salad-with-cranberries-and-pecans-in-radicchio-cups-107265',
#  u'/recipes/food/views/layered-taco-salad-108392',
#  u'/recipes/food/views/french-onion-soup-1858',
#  u'/recipes/food/views/deviled-ham-and-pickle-sandwiches-352286',
#  u'/recipes/food/views/persimmon-wedges-with-toasted-hazelnuts-236537',
#  u'/recipes/food/views/arugula-salad-with-caramelized-onions-goat-cheese-and-candied-walnuts-357496',
#  u'/recipes/food/views/spring-greens-saute-with-bacon-and-walnuts-352538',
#  u'/recipes/food/views/tuna-fresh-mozzarella-and-basil-pizza-242120',
#  u'/recipes/food/views/chioggia-beets-with-raspberry-mint-vinaigrette-232297',
#  u'/recipes/food/views/gramma-pandolfis-pasta-sauce-with-meatballs-56389749',
#  u'/recipes/food/views/kentucky-bourbon-burgoo-395171',
#  u'/recipes/food/views/bruschetta-with-fava-beans-greens-and-blood-oranges-351516',
#  u'/recipes/food/views/jasmine-rice-with-peanuts-and-scallions-232172',
#  u'/recipes/food/views/radicchio-arugula-and-frisee-salad-106040',
#  u'/recipes/food/views/kimchi-fritters-with-soy-dipping-sauce-394667',
#  u'/recipes/food/views/chicken-and-hominy-soup-237029',
#  u'/recipes/food/views/chili-chicken-wings-241548',
#  u'/recipes/food/views/ratatouille-12164',
#  u'/recipes/food/views/lumpia-rolls-352989',
#  u'/recipes/food/views/caramel-chicken-51193220',
#  u'/recipes/food/views/tarragon-lobster-roll-51245010',
#  u'/recipes/food/views/olive-tomato-squares-231164',
#  u'/recipes/food/views/citrus-sage-roast-turkey-breast-with-gravy-small-crowd-51137810',
#  u'/recipes/food/views/spring-potato-salad-with-tuna-318',
#  u'/recipes/food/views/pistachio-ice-cream-5902',
#  u'/recipes/food/views/berry-spinach-salad-with-toasted-hazelnuts',
#  u'/recipes/food/views/seared-cod-with-potato-and-chorizo-hobo-packs-56389763',
#  u'/recipes/food/views/chickpeas-and-chard-with-poached-eggs-51260670',
#  u'/recipes/food/views/gnocchi-101335',
#  u'/recipes/food/views/peppermint-profiteroles-with-chocolate-sauce-5752',
#  u'/recipes/food/views/brochette-de-lapin-aux-pruneaux-368960',
#  u'/recipes/food/views/bacon-and-egg-rice-238390',
#  u'/recipes/food/views/grilled-chicken-with-almond-and-garlic-sauce-363322',
#  u'/recipes/food/views/couscous-and-mograbiah-with-oven-dried-tomatoes-51185030',
#  u'/recipes/food/views/deviled-eggs-with-horseradish-and-black-pepper-238763',
#  u'/recipes/food/views/chicken-and-celery-pot-stickers-358116',
#  u'/recipes/food/views/brunswick-stew-241201',
#  u'/recipes/food/views/chopped-veggie-salad-with-watermelon-and-feta-cheese-242491',
#  u'/recipes/food/views/the-trifecta-burger-366489',
#  u'/recipes/food/views/rice-with-fennel-and-golden-raisins-354197',
#  u'/recipes/food/views/mashed-yukon-gold-potatoes-with-caramelized-shallots-240459',
#  u'/recipes/food/views/chicken-breasts-with-zucchini-pappardelle-354130',
#  u'/recipes/food/views/clementine-olive-and-endive-salad-231352',
#  u'/recipes/food/views/mahi-mahi-fish-tacos-with-chipotle-slaw-and-roasted-pineapple-sauce-51180230',
#  u'/recipes/food/views/roasted-new-potatoes-with-red-onion-garlic-and-pancetta-361812',
#  u'/recipes/food/views/cheese-enchiladas-with-green-sauce-2479',
#  u'/recipes/food/views/black-and-orange-halloween-pasta-356169',
#  u'/recipes/food/views/three-bean-salad-237666',
#  u'/recipes/food/views/korean-marinated-beef-109206',
#  u'/recipes/food/views/meatball-sliders-239792',
#  u'/recipes/food/views/moroccan-spiced-olives-352280',
#  u'/recipes/food/views/quinoa-and-asparagus-salad-with-mimosa-vinaigrette-395372',
#  u'/recipes/food/views/mushroom-stuffed-pork-tenderloin-with-celery-root-mashed-potatoes-5224',
#  u'/recipes/food/views/spicy-peanut-sauce-10602',
#  u'/recipes/food/views/mango-jicama-chopped-salad-102927',
#  u'/recipes/food/views/hearts-of-palm-salad-with-beets-and-blue-cheese-105340',
#  u'/recipes/food/views/bibimbap-at-home-51140460',
#  u'/recipes/food/views/peaches-with-serrano-ham-and-basil-239277',
#  u'/recipes/food/views/tomato-cheddar-pie-56389874',
#  u'/recipes/food/views/gazpacho-bloody-marys-236770',
#  u'/recipes/food/views/guava-stuffed-chicken-with-caramelized-mango-234806',
#  u'/recipes/food/views/potato-and-turnip-gratin-107656',
#  u'/recipes/food/views/savory-chicken-pot-pies-56390046',
#  u'/recipes/food/views/grilled-vegetables-on-onion-rolls-10479',
#  u'/recipes/food/views/swiss-chard-ravioli-101627',
#  u'/recipes/food/views/sea-bass-and-spicy-tomato-sauce-over-braised-fennel-107809',
#  u'/recipes/food/views/eggplant-dip-baba-ghanoush-51121500',
#  u'/recipes/food/views/sun-dried-tomato-and-broccoli-pasta-51188620',
#  u'/recipes/food/views/roasted-japanese-sweet-potatoes-with-scallion-butter-240549',
#  u'/recipes/food/views/grilled-chicken-salad-provencal-107',
#  u'/recipes/food/views/orecchiette-with-savoy-cabbage-peas-and-lemon-cream-107202',
#  u'/recipes/food/views/mango-lime-ice-395130',
#  u'/recipes/food/views/honey-crisp-braised-corned-beef-56389942',
#  u'/recipes/food/views/spring-vegetable-risotto-56389576',
#  u'/recipes/food/views/picadillo-arepa-pie-357978',
#  u'/recipes/food/views/fiery-grilled-shrimp-with-honeydew-gazpacho-368610',
#  u'/recipes/food/views/grilled-eggplant-parmigiana-238668',
#  u'/recipes/food/views/rigatoni-with-eggplant-and-pine-nut-crunch-364033',
#  u'/recipes/food/views/saucy-snapper-with-bay-shrimp-420',
#  u'/recipes/food/views/ham-stuffed-chicken-legs-with-sweet-pepper-honey-and-onion-compote-1964',
#  u'/recipes/food/views/spiced-kurobuta-pork-chops-231434',
#  u'/recipes/food/views/burmese-em-gin-thoke-em-melon-salad-51112760',
#  u'/recipes/food/views/traditional-indian-raita-242185',
#  u'/recipes/food/views/summery-confetti-salad-51183680',
#  u'/recipes/food/views/mussels-a-la-plancha-12686',
#  u'/recipes/food/views/baked-rigatoni-with-sausage-and-mushrooms-231288',
#  u'/recipes/food/views/balsamic-zucchini-109652',
#  u'/recipes/food/views/welsh-rabbit-108892',
#  u'/recipes/food/views/luxe-french-potatoes',
#  u'/recipes/food/views/spicy-marinated-mozzarella-with-oregano-and-capers-106102',
#  u'/recipes/food/views/stuffed-turkey-with-lemon-oregano-and-red-onions-240556',
#  u'/recipes/food/views/crispy-black-bean-tacos-with-feta-and-cabbage-slaw-351271',
#  u'/recipes/food/views/steamed-cod-with-cauliflower-and-saffron-230971',
#  u'/recipes/food/views/spicy-cajun-crab-and-greens-soup-107846',
#  u'/recipes/food/views/peanut-and-scallion-relish-51224040',
#  u'/recipes/food/views/asparagus-ricotta-tart-with-comte-cheese-241852',
#  u'/recipes/food/views/mahi-mahi-with-lemongrass-slaw-and-rice-fritters-236886',
#  u'/recipes/food/views/cured-salmon-with-fennel-and-carrot-salad-51236420',
#  u'/recipes/food/views/baked-lemon-shrimp-with-garlic-11830',
#  u'/recipes/food/views/indian-spiced-chicken-kebabs-with-cilantro-mint-chutney-107682',
#  u'/recipes/food/views/hoppin-john-salad-with-molasses-dressing-236868',
#  u'/recipes/food/views/celery-and-parsnip-soup-with-green-onion-dill-matzo-balls-103226',
#  u'/recipes/food/views/grilled-sichuan-cumin-lamb-chops-with-quick-pickled-cucumbers-51239210',
#  u'/recipes/food/views/persimmon-cake-with-cream-cheese-icing-358789',
#  u'/recipes/food/views/french-fries-352849',
#  u'/recipes/food/views/french-onion-bites-387492',
#  u'/recipes/food/views/fried-artichokes-107787',
#  u'/recipes/food/views/grilled-clams-with-spaghetti-prosciutto-and-mixed-greens-108287',
#  u'/recipes/food/views/beef-and-squash-chili-51259220',
#  u'/recipes/food/views/goat-cheese-and-herb-souffles-105061',
#  u'/recipes/food/views/late-summer-greens-saute-367172',
#  u'/recipes/food/views/dilly-bean-potato-salad-366716',
#  u'/recipes/food/views/swiss-chard-purses-with-sausage-stuffing-231001',
#  u'/recipes/food/views/duck-breast-with-sweet-cherry-sauce-232306',
#  u'/recipes/food/views/soy-ginger-beef-and-noodle-salad-with-peanut-dressing-106946',
#  u'/recipes/food/views/lamb-meatballs-in-green-curry-sauce-369529',
#  u'/recipes/food/views/easy-egg-custard-239229',
#  u'/recipes/food/views/pork-and-squash-stew-with-chiles-51214660',
#  u'/recipes/food/views/roasted-celery-root-red-onions-mushrooms-and-sage-14454',
#  u'/recipes/food/views/farro-radicchio-and-roasted-beet-salad-359409',
#  u'/recipes/food/views/spice-coated-rack-of-lamb-for-two-with-arugula-avocado-and-blood-orange-salad-351234',
#  u'/recipes/food/views/almond-oat-strawberry-shortcakes-395029',
#  u'/recipes/food/views/pasta-bolognese-352493',
#  u'/recipes/food/views/braised-shrimp-and-creamy-endive-107597',
#  u'/recipes/food/views/individual-crispy-loaded-pizza-364769',
#  u'/recipes/food/views/chicken-fajitas-with-crunchy-lime-cabbage-and-avocado-241618',
#  u'/recipes/food/views/farro-salad-with-peas-favas-arugula-and-tomatoes-103415',
#  u'/recipes/food/views/shrimp-in-sherry-butter-sauce-108107',
#  u'/recipes/food/views/grilled-pork-chops-with-chunky-andouille-barbecue-sauce-232557',
#  u'/recipes/food/views/roasted-vegetables-with-pecan-gremolata-236485',
#  u'/recipes/food/views/lemon-pepper-popovers-242299',
#  u'/recipes/food/views/apple-treacle-tart-358596',
#  u'/recipes/food/views/caramelized-onion-flatbreads-with-creme-fraiche-233905',
#  u'/recipes/food/views/basmati-rice-with-summer-vegetable-salad-395910',
#  u'/recipes/food/views/black-bean-corn-burger-367251',
#  u'/recipes/food/views/cucumber-sake-tini-358951',
#  u'/recipes/food/views/roasted-red-pepper-and-tomato-sauce-108314',
#  u'/recipes/food/views/crab-toasts-with-spicy-yogurt-51246810',
#  u'/recipes/food/views/fiesta-veggie-wrap-366989',
#  u'/recipes/food/views/carrots-and-rutabagas-with-lemon-and-honey-105812',
#  u'/recipes/food/views/green-pea-vichyssoise-102102',
#  u'/recipes/food/views/smashed-carrots-241954',
#  u'/recipes/food/views/saigon-chicken-salad-362939',
#  u'/recipes/food/views/grilled-herbed-poussins-242845',
#  u'/recipes/food/views/spiced-chicken-stew-with-carrots-56389612',
#  u'/recipes/food/views/parsley-celery-leaf-and-jicama-salad-355514',
#  u'/recipes/food/views/spicy-steamed-mussels-with-garlic-bread-354269',
#  u'/recipes/food/views/wasabi-and-green-onion-mashed-potatoes-240409',
#  u'/recipes/food/views/flatbread-with-smoked-trout-radishes-and-herbs',
#  u'/recipes/food/views/wild-mushroom-roasted-beet-and-goat-cheese-salad-with-onion-puree-51181400',
#  u'/recipes/food/views/soba-noodle-stir-fry-363380',
#  u'/recipes/food/views/hungarian-cinnamon-loaf-354990',
#  u'/recipes/food/views/mint-granita-109659',
#  u'/recipes/food/views/three-mushroom-dressing-with-prosciutto-240383',
#  u'/recipes/food/views/chunky-jerusalem-artichoke-and-potato-mash-241345',
#  u'/recipes/food/views/sweet-corn-flans-with-tomato-corn-relish-103544',
#  u'/recipes/food/views/cuban-avocado-watercress-and-pineapple-salad-em-ensalada-de-aguacate-berro-y-pina-em-51203230',
#  u'/recipes/food/views/a-better-granola-51143850',
#  u'/recipes/food/views/shepherds-pie-107418',
#  u'/recipes/food/views/butternut-squash-and-cheddar-bread-pudding-355792',
#  u'/recipes/food/views/summer-vegetable-succotash-105227',
#  u'/recipes/food/views/creamy-white-bean-and-chorizo-soup-233903',
#  u'/recipes/food/views/grilled-pork-loin-with-fire-roasted-pineapple-salsa-241945',
#  u'/recipes/food/views/herb-salad-with-feta-roasted-red-peppers-and-toasted-nuts-360550',
#  u'/recipes/food/views/crispy-bruschetta-with-goat-cheese-tomatoes-and-mint-103220',
#  u'/recipes/food/views/cornish-game-hens-with-pancetta-juniper-berries-and-beets-103010',
#  u'/recipes/food/views/masa-cornbread-stuffing-with-chiles-361732',
#  u'/recipes/food/views/potato-galettes-with-crab-shrimp-and-asparagus-105064',
#  u'/recipes/food/views/leaving-home-penne-rigate-with-broccoli-365089',
#  u'/recipes/food/views/grilled-summer-lobster-103612',
#  u'/recipes/food/views/dry-chimichurri-rub-240753',
#  u'/recipes/food/views/roasted-sesame-and-panko-coated-asparagus-with-soy-ginger-drizzle-241905',
#  u'/recipes/food/views/roasted-cauliflower-and-radicchio-salad-230966',
#  u'/recipes/food/views/vietnamese-tuna-burger-367232',
#  u'/recipes/food/views/standing-rib-roast-with-potatoes-and-portobello-mushrooms-13630',
#  u'/recipes/food/views/daves-tomato-and-cucumber-salad-108504',
#  u'/recipes/food/views/shrimp-and-vegetable-salad-with-roasted-tomato-vinaigrette-236043',
#  u'/recipes/food/views/oil-and-vinegar-potato-salad-353830',
#  u'/recipes/food/views/quick-poached-salmon-with-speedy-ratatouille',
#  u'/recipes/food/views/broiled-lamb-chops-with-mint-chimichurri-356010',
#  u'/recipes/food/views/wild-rice-dressing-with-roasted-grapes-and-walnuts-240384',
#  u'/recipes/food/views/red-snapper-with-coconut-clam-broth',
#  u'/recipes/food/views/roasted-cauliflower-with-onions-and-fennel-237336',
#  u'/recipes/food/views/pickled-red-onions-356753']

# %%
recipesDf = pd.DataFrame.from_dict(recipes)
recipesDf.to_pickle('recipesDb2')
oldRecipesDf.to_pickle('recipesDb1')

# %% [markdown]
# ### get food spoilage dates

# %%
### get food spoilage dates
foodSpoilURL = "http://ohmyveggies.com/how-to-prevent-food-spoilage-with-careful-meal-planning/"
#page = urllib2.urlopen(foodSpoilURL)
hdr = {'User-Agent':'Mozilla/5.0'}
req = urllib2.Request(foodSpoilURL,headers=hdr)
page = urllib2.urlopen(req)
foodSpoilSoup = BeautifulSoup(page, "html.parser")
foodSpoilHtml = foodSpoilSoup.findAll("p")

# %%
foodSpoilsinDate12Days = foodSpoilHtml[7].get_text().split()
foodSpoilsin35Days = foodSpoilHtml[9].get_text().split()
foodSpoilsin67Days = foodSpoilHtml[11].get_text().split()
foodSpoilsGreatWeek = foodSpoilHtml[13].get_text().split()
foodSpoilDates = [foodSpoilsinDate12Days, foodSpoilsin35Days, foodSpoilsin67Days, foodSpoilsGreatWeek]
with open("foodspoils.txt", "wb") as fo:
    pickle.dump(foodSpoilDates, fo)

# %% [markdown]
# ### Create a SQL database for my data

# %%
dbname = 'recipes_db'
username = 'nemo'
pswd = 'eatsalot'

engine = create_engine('postgresql://%s:%s@localhost/%s'%(username,pswd,dbname))
print engine.url

# %%
## create a database (if it doesn't exist)
if not database_exists(engine.url):
    create_database(engine.url)
print(database_exists(engine.url))

# %%
reviewText

# %%
len(letters)

# %% [markdown]
# ### Parse a list of vegetables!

# %%
from nltk.stem.wordnet import WordNetLemmatizer
def lemmatizePhrase(phrase):
    """ 
    Lemmatize each word in a pharse
    """
    words = phrase.lower().split()
    return ' '.join(WordNetLemmatizer().lemmatize(word) for word in words)

ingredientsURL = "https://en.m.wikibooks.org/wiki/Cookbook:Ingredients"
page = urllib2.urlopen(ingredientsURL)
ingredientsSoup = BeautifulSoup(page, "html.parser")
ingredientsHtml = ingredientsSoup.findAll("li")
ingredients = []

for ingredient in ingredientsHtml:
    if ingredient.a is not None:
        ingredients.append(lemmatizePhrase(ingredient.a.get_text()))

ingredients = list(set(ingredients))
ingredients.remove('cc by-sa 3.0')
ingredients.remove('')
ingredients.remove('edit')
ingredients.remove('desktop')
ingredients.remove('privacy')
ingredients.remove('soda, baking')
veggies = []
for veggie in veggieList:
    ingredients.append(lemmatizePhrase(veggie.lower()))
    veggies.append(lemmatizePhrase(veggie.lower()))
ingredients = list(set(ingredients))
with open("ingredients.txt", "wb") as fo:
    pickle.dump(ingredients, fo)
with open("veggies.txt", "wb") as fo:
    pickle.dump(veggies, fo)

# %% [markdown]
# ### Parse a list of food adjectives

# %%
foodAdjectivesURL = "https://foxhugh.com/word-lists/list-of-food-adjectives/"
page = urllib2.urlopen(foodAdjectivesURL)
foodAdjectivesSoup = BeautifulSoup(page, "html.parser")
foodAdjectivesHtml = foodAdjectivesSoup.findAll("p")
adjectives = []
for adjective in foodAdjectivesHtml:
    adjectives.append(lemmatizePhrase(adjective.get_text()))
adjectives = adjectives[1:302]
with open("adjectives.txt", "wb") as fo:
    pickle.dump(adjectives, fo)

# %%
for veggie in veggieList:
    ingredients.append(lemmatizePhrase(veggie.lower()))

# %%
len(ingredients)

# %%
len(list(set(ingredients)))
